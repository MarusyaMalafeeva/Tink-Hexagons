# %%
import pandas as pd

# %%
czhat = pd.read_csv('hexagons_dataset.csv')
# Out:
# C:\Users\Marusya\AppData\Local\Temp\ipykernel_23028\3289097129.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   czhat = pd.read_csv('hexagons_dataset.csv')

# %%
czhat.head(60)
# Out:
#     Unnamed: 0              hex               subject treatment_date  \
# 0            0  88212662adfffff  Оренбургская область     2022-09-22
# 1            1  8821233569fffff  Оренбургская область     2022-09-22
# 2            2  882124d31bfffff  Оренбургская область     2022-09-22
# 3            3  882123a89dfffff  Оренбургская область     2022-09-22
# 4            4  882105c02bfffff  Оренбургская область     2022-09-22
# 5            5  8821244561fffff  Оренбургская область     2022-09-22
# 6            6  8810881a4dfffff  Оренбургская область     2022-09-22
# 7            7  882123391dfffff  Оренбургская область     2022-09-22
# 8            8  88108890a5fffff  Оренбургская область     2022-09-22
# 9            9  882122345bfffff  Оренбургская область     2022-09-22
# 10          10  8821260433fffff  Оренбургская область     2022-09-22
# 11          11  881088d881fffff  Оренбургская область     2022-09-22
# 12          12  88108a19edfffff  Оренбургская область     2022-09-22
# ...

# %%
exts = '', '.gz', '.bz2', '.zip', '.xz'

for ext in exts: czhat.to_csv(f'hexagons_dataset.csv{ext}')
